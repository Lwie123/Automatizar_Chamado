# %%
# MÓDULO DE CHAMADO EM ANDAMENTO
from selenium import webdriver
import time
import pyautogui
import pyperclip
from selenium.webdriver.common.keys import Keys
from datetime import date
from datetime import datetime

pyautogui.PAUSE = 2

# CRIAÇÃO DAS VARIÁVEIS

numero = input("Insira o número da iteração:")
itera = int(input("Quantas vezes serão feitas?"))
memo_padrao = ""
data = ""
hora = ""
horafinal = ""

# ABRE O CHROME

navegador = webdriver.Chrome()

# ENTRA NO SITE E ENTRA COM LOGIN E SENHA

navegador.get("https://inorpelsecurity.desk.ms/")
time.sleep(3)
navegador.find_element_by_xpath('//*[@id="ModalDirecionaPrefixo"]/div/div/div[2]/form/div[3]/button').click()
time.sleep(3)
navegador.find_element_by_xpath('//*[@id="ModalLoginTicket"]/div/div/div[2]/form/div[1]/input').send_keys("matheus.gomes")
navegador.find_element_by_xpath('//*[@id="ModalLoginTicket"]/div/div/div[2]/form/div[2]/input').send_keys("In@2021!")
navegador.find_element_by_xpath('//*[@id="ModalLoginTicket"]/div/div/div[2]/form/div[3]/button').click()
time.sleep(5)

# ACESSA A PÁGINA DE CHAMADOS

navegador.find_element_by_xpath('//*[@id="HomeTicket"]/div[1]/div[3]/div/div/div/a/div/div[2]').click()
time.sleep(4)


for i in range(itera):

    # PROCURA O CHAMADO PELO NÚMERO 

    navegador.find_element_by_xpath('//*[@id="PanelChamadosSuporte"]/div[2]/div[2]/div/div[1]/div/div/div/input').click()
    time.sleep(1)
    pyautogui.hotkey('ctrl', 'a')
    pyautogui.press('backspace')
    pyperclip.copy(numero)
    pyautogui.hotkey('ctrl', 'v')
    navegador.find_element_by_xpath('//*[@id="PanelChamadosSuporte"]/div[2]/div[2]/div/div[1]/div/div/div/div/button[1]').click()
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="PanelChamadosSuporte"]/div[2]/div[2]/div/div[2]/table/tbody/tr/td[1]').click()
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="Aba1ChamadosSuporte"]/form[2]/ul/li[1]/div[1]').click()
    time.sleep(3)

    # EDITA O CHAMADO

    data = datetime.now()
    hora = data.strftime('%d/%m/%Y %H:%M')
    horafinal = hora[-5:]
    navegador.find_element_by_xpath('//*[@id="Aba1InteragirChamadosSuporte"]/div[15]/div[1]/div[2]/input').send_keys(horafinal)

    navegador.find_element_by_xpath('//*[@id="Aba1InteragirChamadosSuporte"]/div[2]/div[1]/span/span[1]/span').click()
    time.sleep(2)
    navegador.find_element_by_xpath('/html/body/span/span/span[1]/input').send_keys("Desk")
    time.sleep(2)
    pyautogui.press("ENTER")
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="Aba1InteragirChamadosSuporte"]/div[3]/div[1]/span/span[1]/span').click()
    time.sleep(2)
    navegador.find_element_by_xpath('/html/body/span/span/span[1]/input').send_keys("Andamento")
    time.sleep(2)
    pyautogui.press("ENTER")
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="Aba1InteragirChamadosSuporte"]/div[12]/div[1]/span/span[1]/span').click()
    time.sleep(2)
    navegador.find_element_by_xpath('/html/body/span/span/span[1]/input').send_keys("Chamado em Andamento")
    time.sleep(2)
    pyautogui.press("ENTER")
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="ModalInteragirChamadosSuporte"]/div/div/div[3]/div/div/div/button[2]').click()
    time.sleep(5)
    navegador.find_element_by_xpath('//*[@id="ModalChamadosSuporte"]/div/div/div[3]/div/div/div/button[1]').click()
    numero = int(numero) - 1
    time.sleep(5)
# Out:
# Insira o número da iteração:98
# Quantas vezes serão feitas?18

# %%
# MÓDULO DE CHAMADO RESOLVIDO
from selenium import webdriver
import time
import pyautogui
import pyperclip
from selenium.webdriver.common.keys import Keys
from datetime import date
from datetime import datetime

pyautogui.PAUSE = 2

# CRIAÇÃO DAS VARIÁVEIS

numero = input("Insira o número da iteração:")
itera = int(input("Quantas vezes serão feitas?"))
memo_padrao = "Feito relatório e enviado ao respectivo cliente."
data = ""
hora = ""
horafinal = ""

# ABRE O CHROME

navegador = webdriver.Chrome()

# ENTRA NO SITE E ENTRA COM LOGIN E SENHA

navegador.get("https://inorpelsecurity.desk.ms/")
time.sleep(3)
navegador.find_element_by_xpath('//*[@id="ModalDirecionaPrefixo"]/div/div/div[2]/form/div[3]/button').click()
time.sleep(3)
navegador.find_element_by_xpath('//*[@id="ModalLoginTicket"]/div/div/div[2]/form/div[1]/input').send_keys("matheus.gomes")
navegador.find_element_by_xpath('//*[@id="ModalLoginTicket"]/div/div/div[2]/form/div[2]/input').send_keys("In@2021!")
navegador.find_element_by_xpath('//*[@id="ModalLoginTicket"]/div/div/div[2]/form/div[3]/button').click()
time.sleep(3)

# ACESSA A PÁGINA DE CHAMADOS

navegador.find_element_by_xpath('//*[@id="HomeTicket"]/div[1]/div[3]/div/div/div/a/div/div[2]').click()
time.sleep(4)


for i in range(itera):

    # PROCURA O CHAMADO PELO NÚMERO 

    navegador.find_element_by_xpath('//*[@id="PanelChamadosSuporte"]/div[2]/div[2]/div/div[1]/div/div/div/input').click()
    time.sleep(1)
    pyautogui.hotkey('ctrl', 'a')
    pyautogui.press('backspace')
    pyperclip.copy(numero)
    pyautogui.hotkey('ctrl', 'v')
    navegador.find_element_by_xpath('//*[@id="PanelChamadosSuporte"]/div[2]/div[2]/div/div[1]/div/div/div/div/button[1]').click()
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="PanelChamadosSuporte"]/div[2]/div[2]/div/div[2]/table/tbody/tr/td[1]').click()
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="Aba1ChamadosSuporte"]/form[2]/ul/li[1]/div[1]').click()
    time.sleep(3)

    # EDITA O CHAMADO

    data = datetime.now()
    hora = data.strftime('%d/%m/%Y %H:%M')
    horafinal = hora[-5:]
    navegador.find_element_by_xpath('//*[@id="Aba1InteragirChamadosSuporte"]/div[15]/div[1]/div[2]/input').send_keys(horafinal)

    navegador.find_element_by_xpath('//*[@id="Aba1InteragirChamadosSuporte"]/div[2]/div[1]/span/span[1]/span').click()
    time.sleep(2)
    navegador.find_element_by_xpath('/html/body/span/span/span[1]/input').send_keys("Desk")
    time.sleep(2)
    pyautogui.press("ENTER")
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="Aba1InteragirChamadosSuporte"]/div[3]/div[1]/span/span[1]/span').click()
    time.sleep(2)
    navegador.find_element_by_xpath('/html/body/span/span/span[1]/input').send_keys("Resolvido")
    time.sleep(2)
    pyautogui.press("ENTER")
    time.sleep(4)
    navegador.find_element_by_xpath('//*[@id="Aba1InteragirChamadosSuporte"]/div[4]/div[1]/span/span[1]/span').click()
    time.sleep(2)
    navegador.find_element_by_xpath('/html/body/span/span/span[1]/input').send_keys("Atualização")
    time.sleep(2)
    pyautogui.press("ENTER")
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="Aba1InteragirChamadosSuporte"]/div[13]/div/textarea').send_keys(memo_padrao)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="ModalInteragirChamadosSuporte"]/div/div/div[3]/div/div/div/button[2]').click()
    time.sleep(3)
    navegador.find_element_by_xpath('//*[@id="ModalChamadosSuporte"]/div/div/div[3]/div/div/div/button[1]').click()
    numero = int(numero) - 1
    time.sleep(5)
# Out:
# Insira o número da iteração:98
# Quantas vezes serão feitas?18
